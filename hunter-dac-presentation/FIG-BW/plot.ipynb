# %%
# ipython -c "%run plot.ipynb"

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd

# Paper specific settings
STANDARD_WIDTH = 17.8
SINGLE_COL_WIDTH = STANDARD_WIDTH / 2
DOUBLE_COL_WIDTH = STANDARD_WIDTH
PPT_WIDTH = 32.25
PPT_FONT_SIZE=20
def cm_to_inch(value):
    return value/2.54
    
# matplotlib style settings
matplotlib.rcParams['text.usetex'] = False
style.use('seaborn-white')
plt.rcParams["axes.grid"] = False
plt.rcParams["axes.grid.axis"] = "y"
plt.rcParams["grid.linewidth"] = 0.8
plt.rcParams['hatch.linewidth'] = 0.5
plt.rcParams["font.family"] = "Nimbus Roman"
pd.options.display.max_columns = None
pd.options.display.max_rows = None


# Data Preprocessing
# with open("./avg-test-result-in-paper", "r") as f:
with open("./performance-comparison-table", "r") as f:
    df = pd.read_csv(f, delim_whitespace=True, index_col=None, engine='python')
# Plotting Settings
fig = plt.figure(dpi = 300, figsize = (cm_to_inch(PPT_WIDTH), cm_to_inch(8)))
fontsize=PPT_FONT_SIZE
bar_width = 0.2
linewidth = 1
subfig_titles = ["(a) 0% dup ratio", "(b) 25% dup ratio", "(c) 50% dup ratio", "(d) 75% dup ratio"]
patterns = ['///', '\\\\\\', '', 'XXX']
# Reference: https://designbro.com/blog/inspiration/color-combinations/
colors = ["white", "#3F97D3", "#FFBFBF", "#ef233c"]

x = [1, 2, 3, 4, 5, 6, 7]
fss = df['file_system'].drop_duplicates().reset_index().drop(columns=['index'])['file_system']
tot = len(fss) * bar_width
print(fss)
for idx, fs in enumerate(fss):
    points = []
    for pivot in x:
        point = pivot - tot / 2 + bar_width / 2 + idx * bar_width
        points.append(point)
    if fs == "PMM":
        plt.axhline(2259.2 / 1024, color=colors[idx], linestyle='--', linewidth=2*linewidth)
    else:
        plt.bar(points, df[df['file_system'] == fs]['bandwidth(MiB/s)'] / 1024, width=bar_width, hatch=patterns[idx], edgecolor='black', color=colors[idx], linewidth=linewidth, yerr=df[df['file_system'] == fs]['std-bandwidth(MiB/s)'] / 1024, error_kw=dict(lw=linewidth, capsize=3, capthick=1))

# Draw title
plt.xticks(x, labels=[1, 2, 4, 8, 16, 32, 64], fontsize=fontsize)
plt.yticks([0, 0.5, 1, 1.5, 2, 2.5], fontsize=fontsize)
plt.ylabel('BW (GiB/s)', fontsize=fontsize)
plt.xlabel("File Size (GiB)", fontsize=fontsize) 
            
fig.legend(["PM", "NOVA", "PMFS", "HUNTER"], loc='center', bbox_to_anchor=(0.5, 1), ncol=4, fontsize=fontsize)
ax = fig.gca()
lw = 1
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(lw)
plt.tight_layout()
plt.savefig("./FIG-BW.pdf", bbox_inches='tight', pad_inches=0)
# Out:
# /tmp/ipykernel_35856/2588200600.py:19: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn-white')
# 0      NOVA
# 1      PMFS
# 2    HUNTER
# 3       PMM
# Name: file_system, dtype: object

# %% [markdown]
# # For Poster

# %%
# ipython -c "%run plot.ipynb"

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd

# Paper specific settings
STANDARD_WIDTH = 17.8
SINGLE_COL_WIDTH = STANDARD_WIDTH / 2
DOUBLE_COL_WIDTH = STANDARD_WIDTH
PPT_WIDTH = 32.25
PPT_FONT_SIZE=20
def cm_to_inch(value):
    return value/2.54
    
# matplotlib style settings
matplotlib.rcParams['text.usetex'] = False
style.use('seaborn-white')
plt.rcParams["axes.grid"] = False
plt.rcParams["axes.grid.axis"] = "y"
plt.rcParams["grid.linewidth"] = 0.8
plt.rcParams['hatch.linewidth'] = 0.5
plt.rcParams["font.family"] = "Nimbus Roman"
pd.options.display.max_columns = None
pd.options.display.max_rows = None


# Data Preprocessing
# with open("./avg-test-result-in-paper", "r") as f:
with open("./performance-comparison-table", "r") as f:
    df = pd.read_csv(f, delim_whitespace=True, index_col=None, engine='python')

df.drop(df[df['file_system'] == "HUNTER"].index, inplace=True)

# Plotting Settings
fig = plt.figure(dpi = 300, figsize = (cm_to_inch(PPT_WIDTH), cm_to_inch(10)))
fontsize=PPT_FONT_SIZE
bar_width = 0.2
linewidth = 1
subfig_titles = ["(a) 0% dup ratio", "(b) 25% dup ratio", "(c) 50% dup ratio", "(d) 75% dup ratio"]
patterns = ['///', '\\\\\\', '', 'XXX']
# Reference: https://designbro.com/blog/inspiration/color-combinations/
# colors = ["white", "#3F97D3", "#FFBFBF", "#ef233c"]
colors = ["white", "#3F97D3", "#ef233c"]

x = [1, 2, 3, 4, 5, 6, 7]
fss = df['file_system'].drop_duplicates().reset_index().drop(columns=['index'])['file_system']
tot = len(fss) * bar_width
print(fss)
for idx, fs in enumerate(fss):
    points = []
    for pivot in x:
        point = pivot - tot / 2 + bar_width / 2 + idx * bar_width + 0.1
        points.append(point)
    if fs == "PMM":
        plt.axhline(2259.2 / 1024, color=colors[idx], linestyle='--', linewidth=2*linewidth)
    else:
        plt.bar(points, df[df['file_system'] == fs]['bandwidth(MiB/s)'] / 1024, width=bar_width, hatch=patterns[idx], edgecolor='black', color=colors[idx], linewidth=linewidth, yerr=df[df['file_system'] == fs]['std-bandwidth(MiB/s)'] / 1024, error_kw=dict(lw=linewidth, capsize=3, capthick=1))

# Draw title
plt.xticks(x, labels=[1, 2, 4, 8, 16, 32, 64], fontsize=fontsize)
plt.yticks([0, 0.5, 1, 1.5, 2, 2.5], fontsize=fontsize)
plt.ylabel('BW (GiB/s)', fontsize=fontsize)
plt.xlabel("File Size (GiB)", fontsize=fontsize) 
            
fig.legend(["PM", "NOVA", "PMFS", "HUNTER"], loc='center', bbox_to_anchor=(0.5, 1), ncol=4, fontsize=fontsize)
ax = fig.gca()
lw = 1
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(lw)
plt.tight_layout()
plt.savefig("./FIG-BW-poster.pdf", bbox_inches='tight', pad_inches=0)
# Out:
# /tmp/ipykernel_749426/1852767680.py:19: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   style.use('seaborn-white')
# 0    NOVA
# 1    PMFS
# 2     PMM
# Name: file_system, dtype: object
