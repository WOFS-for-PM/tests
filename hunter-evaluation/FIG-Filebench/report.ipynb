# %%
import pandas as pd

with open("./performance-comparison-table", "r") as f:
    df = pd.read_csv(f, delim_whitespace=True, engine='python')
df.head()
# Out:
#   file_system    file_bench  threads        iops
# 0      HUNTER  fileserver.f        1   58339.150
# 1      HUNTER  fileserver.f        2   90085.465
# 2      HUNTER  fileserver.f        3  116413.125
# 3      HUNTER  fileserver.f        4  129598.950
# 4      HUNTER  fileserver.f        5  133269.688

# %% [markdown]
# # The performance improvement of HUNTER over other PM file systems in Fileserver.

# %%
fs_df = df[df['file_bench'] == 'fileserver.f']

fs_names = fs_df['file_system'].drop_duplicates().reset_index().drop(columns=['index'])['file_system']

hunter =  fs_df[fs_df["file_system"] == "HUNTER-J"].copy().reset_index()

for fs_name in fs_names:
    if fs_name == "HUNTER-J":
        continue
    fs = fs_df[fs_df["file_system"] == fs_name]
    hunter[fs_name] = hunter["iops"] / fs["iops"].reset_index()["iops"]

hunter
# Out:
#     index file_system    file_bench  threads        iops    HUNTER      PMFS  \
# 0      64    HUNTER-J  fileserver.f        1   66060.584  1.132354  1.419737
# 1      65    HUNTER-J  fileserver.f        2   96682.564  1.073232  1.290899
# 2      66    HUNTER-J  fileserver.f        3  127907.005  1.098734  1.381479
# 3      67    HUNTER-J  fileserver.f        4  137260.456  1.059117  1.386282
# 4      68    HUNTER-J  fileserver.f        5  138646.254  1.040344  1.348622
# 5      69    HUNTER-J  fileserver.f        6  137783.037  1.038186  1.336710
# 6      70    HUNTER-J  fileserver.f        7  135735.606  1.033335  1.323690
# 7      71    HUNTER-J  fileserver.f        8  132272.297  1.029885  1.311484
# 8      72    HUNTER-J  fileserver.f        9  126644.290  1.023151  1.251450
# 9      73    HUNTER-J  fileserver.f       10  119199.609  1.012616  1.198225
# 10     74    HUNTER-J  fileserver.f       11  111423.635  1.002716  1.122334
# 11     75    HUNTER-J  fileserver.f       12  104876.662  0.994813  1.068160
# 12     76    HUNTER-J  fileserver.f       13   99086.547  0.987267  1.006008
# 13     77    HUNTER-J  fileserver.f       14   95154.136  0.988165  0.985067
# 14     78    HUNTER-J  fileserver.f       15   93203.389  1.002615  0.966076
# 15     79    HUNTER-J  fileserver.f       16   91208.207  1.001161  0.949934
#
#         NOVA  NOVA-RELAX  SplitFS-FILEBENCH  EXT4-DAX   XFS-DAX
# 0   1.399909    1.347061           2.074851  2.679299  3.583500
# 1   1.244496    1.223395           1.999213  2.281091  3.680257
# 2   1.266470    1.241365           2.236000  2.259710  3.502490
# 3   1.229559    1.211717           2.212647  2.082027  2.914520
# 4   1.152582    1.150739           2.140898  1.941456  3.151233
# 5   1.162267    1.151507           2.100904  1.843417  3.153906
# 6   1.173214    1.166808           2.069966  1.744637  3.061583
# 7   1.172335    1.163119           2.026607  1.694528  2.876606
# 8   1.154045    1.139808           1.968760  1.689920  2.728925
# 9   1.114397    1.101356           1.885967  1.714282  2.480254
# 10  1.070157    1.053721           1.788071  1.689406  2.292352
# 11  1.025574    1.008447           1.700670  1.744065  2.150830
# 12  0.990989    0.963779           1.557495  1.726199  2.012304
# 13  0.970496    0.940571           1.595490  1.746143  1.967609
# 14  0.977255    0.934689           1.571585  1.850466  2.072730
# 15  0.995354    0.942537           1.563240  1.839034  1.927407

# %% [markdown]
# # The performance improvement of HUNTER over other PM file systems in Varmail.

# %%
fs_df = df[df['file_bench'] == 'varmail.f']

fs_names = fs_df['file_system'].drop_duplicates().reset_index().drop(columns=['index'])['file_system']

hunter =  fs_df[fs_df["file_system"] == "HUNTER-J"].copy().reset_index()

for fs_name in fs_names:
    if fs_name == "HUNTER-J":
        continue
    fs = fs_df[fs_df["file_system"] == fs_name]
    hunter[fs_name] = hunter["iops"] / fs["iops"].reset_index()["iops"]

hunter
# Out:
#     index file_system file_bench  threads         iops    HUNTER      PMFS  \
# 0      80    HUNTER-J  varmail.f        1   357279.576  1.994627  1.350661
# 1      81    HUNTER-J  varmail.f        2   571142.874  2.104074  1.285050
# 2      82    HUNTER-J  varmail.f        3   765587.211  2.265814  1.307551
# 3      83    HUNTER-J  varmail.f        4   919767.199  2.357998  1.361210
# 4      84    HUNTER-J  varmail.f        5  1066798.432  2.437071  1.477927
# 5      85    HUNTER-J  varmail.f        6  1165363.039  2.435664  1.596609
# 6      86    HUNTER-J  varmail.f        7  1239751.508  2.416758  1.720633
# 7      87    HUNTER-J  varmail.f        8  1289133.830  2.365146  1.813116
# 8      88    HUNTER-J  varmail.f        9  1327816.873  2.320874  1.865001
# 9      89    HUNTER-J  varmail.f       10  1356021.763  2.277465  1.912987
# 10     90    HUNTER-J  varmail.f       11  1378106.468  2.236953  1.941378
# 11     91    HUNTER-J  varmail.f       12  1358137.256  2.147533  1.920647
# 12     92    HUNTER-J  varmail.f       13  1362392.157  2.111013  1.927242
# 13     93    HUNTER-J  varmail.f       14  1359092.982  2.076770  1.931576
# 14     94    HUNTER-J  varmail.f       15  1362242.625  2.056104  1.933169
# 15     95    HUNTER-J  varmail.f       16  1323042.125  1.984191  1.901041
#
#         NOVA  NOVA-RELAX  SplitFS-FILEBENCH  EXT4-DAX   XFS-DAX
# 0   1.461525    1.258720           3.320953  3.570496  4.028410
# 1   1.403348    1.220616           3.277270  4.186464  4.665328
# 2   1.409980    1.222135           3.215448  4.684532  4.747150
# 3   1.389155    1.209091           3.103020  4.910413  4.585846
# 4   1.387278    1.201660           3.036797  5.237231  4.569631
# 5   1.373699    1.180853           2.894553  5.245829  4.482663
# 6   1.358656    1.167927           2.752087  5.205740  4.404395
# 7   1.333221    1.154007           2.613421  5.218926  4.300647
# 8   1.313029    1.158588           2.499447  5.145457  4.204153
# 9   1.308070    1.150306           2.370396  5.029696  4.103534
# 10  1.311501    1.150565           2.273233  4.932653  4.027482
# 11  1.294061    1.108971           2.113741  4.759085  3.825074
# 12  1.297983    1.108965           2.027800  4.644792  3.727339
# 13  1.288784    1.103215           1.945358  4.550624  3.642302
# 14  1.297462    1.111796           1.908449  4.473367  3.564877
# 15  1.271634    1.075342           1.793570  4.218668  3.422794

# %% [markdown]
# # The performance improvement of HUNTER over HUNTER-naive.

# %%
hunter_j = df[df["file_system"] == "HUNTER-J"].copy().reset_index()
hunter = df[df["file_system"] == "HUNTER"].copy().reset_index()

hunter_j["HUNTER-J"] = hunter_j["iops"] / hunter["iops"].reset_index()["iops"]

print(hunter_j.min()["HUNTER-J"], hunter_j.max()["HUNTER-J"])
# hunter_j
# Out:
# 0.9840799437765765 2.4370707664824303
