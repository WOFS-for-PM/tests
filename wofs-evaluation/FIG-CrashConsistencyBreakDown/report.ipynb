# %% [markdown]
# # How does KILLER's per-operation metadata I/O faster than the NOVA, SplitFS, and PMFS?

# %%
import pandas as pd
import numpy as np

ops = [
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47087 * 60, 264382 * 60, 502315 * 60, 263680 * 60], # NOVA
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 31838 * 60, 107583 * 60, 171224 * 60, 113574 * 60], # SplitFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47205 * 60, 268363 * 60, 558425 * 60, 183316 * 60], # PMFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 79240 * 60, 437532 * 60, 580830 * 60, 344069 * 60], # KILLER
]

killer = "./performance-comparison-table-KILLER"
files = ["./performance-comparison-table-NOVA", "./performance-comparison-table-SplitFS", "./performance-comparison-table-PMFS"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]

with open(killer, "r") as f:
    df_killer = pd.read_csv(f, delim_whitespace=True, engine='python')

for file in files:
    with open(file, "r") as f:
        print(file)
        df = pd.read_csv(f, delim_whitespace=True, engine='python')
        min_improvement = 99999999
        max_improvement = 0
        for workload in workloads:
            s = df[(df['workloads'] == workload)]
            # sum all cols of s instead of the first two
            # s = s.iloc[:, 2:]
            s = s.sum(axis=1) / ops[files.index(file)][workloads.index(workload)]
            # print(s)
            s_killer = df_killer[(df_killer['workloads'] == workload)]
            # sum all cols of s_killer
            # s_killer = s_killer.iloc[:, 2:]
            s_killer = s_killer.sum(axis=1) / ops[3][workloads.index(workload)]
            
            improvement = (s - s_killer) / s
            if improvement.values[0] < min_improvement:
                min_improvement = improvement.values[0]
            if improvement.values[0] > max_improvement:
                max_improvement = improvement.values[0]
        
        print("min improvement: ", min_improvement)
        print("max improvement: ", max_improvement)
# Out:
# ./performance-comparison-table-NOVA
# min improvement:  0.13502484885108557
# max improvement:  0.7659802171404732
# ./performance-comparison-table-SplitFS
# min improvement:  0.3266643833390039
# max improvement:  0.863983680565989
# ./performance-comparison-table-PMFS
# min improvement:  0.05714856603924744
# max improvement:  0.7483050327595694

# %% [markdown]
# # How much metadata I/O time do PMFS, SplitFS, and NOVA spend per operation?

# %%
import pandas as pd
import numpy as np

ops = [
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47087 * 60, 264382 * 60, 502315 * 60, 263680 * 60], # NOVA
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 31838 * 60, 107583 * 60, 171224 * 60, 113574 * 60], # SplitFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47205 * 60, 268363 * 60, 558425 * 60, 183316 * 60], # PMFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 79240 * 60, 437532 * 60, 580830 * 60, 344069 * 60], # KILLER
]

files = ["./performance-comparison-table-NOVA", "./performance-comparison-table-SplitFS", "./performance-comparison-table-PMFS"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]

for file in files:
    with open(file, "r") as f:
        print(file)
        df = pd.read_csv(f, delim_whitespace=True, engine='python')
        for workload in workloads:
            s = df[(df['workloads'] == workload)]
            s = s.sum(axis=1).values[0]
            d = df[(df['workloads'] == workload)]['D(ns)'].values[0]
            print((s-d)/s)
# Out:
# ./performance-comparison-table-NOVA
# 0.7549408732854028
# 0.689210469535136
# 0.38375878876593644
# 0.5627263532020492
# 0.11344770619189085
# 0.312858584258666
# ./performance-comparison-table-SplitFS
# 0.8189702302563908
# 0.8481609157439394
# 0.6383692402292489
# 0.9177163918181542
# 0.9738725626426723
# 0.8553746311198425
# ./performance-comparison-table-PMFS
# 0.7454992566479379
# 0.7250994300691181
# 0.5477058247651525
# 0.7654877982745656
# 0.22895784002635125
# 0.6974738293190695

# %% [markdown]
# # How much metadata commit I/O time do PMFS and SplitFS spend per operation?

# %%
import pandas as pd
import numpy as np

ops = [
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47087 * 60, 264382 * 60, 502315 * 60, 263680 * 60], # NOVA
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 31838 * 60, 107583 * 60, 171224 * 60, 113574 * 60], # SplitFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47205 * 60, 268363 * 60, 558425 * 60, 183316 * 60], # PMFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 79240 * 60, 437532 * 60, 580830 * 60, 344069 * 60], # KILLER
]
# "./performance-comparison-table-NOVA", 
files = ["./performance-comparison-table-SplitFS", "./performance-comparison-table-PMFS"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]

for file in files:
    with open(file, "r") as f:
        print(file)
        df = pd.read_csv(f, delim_whitespace=True, engine='python')
        for workload in workloads:
            s = df[(df['workloads'] == workload)]
            s = s.sum(axis=1).values[0]
            m = df[(df['workloads'] == workload)]['M(ns)'].values[0]
            print(m/s)
# Out:
# ./performance-comparison-table-SplitFS
# 0.764041545274836
# 0.8481605520024479
# 0.5793954428103706
# 0.8550286027079538
# 0.9725710115136263
# 0.8154138574913822
# ./performance-comparison-table-PMFS
# 0.2535544791883322
# 0.26655897694226915
# 0.17162603794934797
# 0.49657636038614883
# 0.16163641936566145
# 0.5840928513696264

# %% [markdown]
# # NOVA Overheads

# %%
import pandas as pd
import numpy as np

ops = [
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47087 * 60, 264382 * 60, 502315 * 60, 263680 * 60], # NOVA
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 31838 * 60, 107583 * 60, 171224 * 60, 113574 * 60], # SplitFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47205 * 60, 268363 * 60, 558425 * 60, 183316 * 60], # PMFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 79240 * 60, 437532 * 60, 580830 * 60, 344069 * 60], # KILLER
]
# "./performance-comparison-table-NOVA", 
files = ["./performance-comparison-table-NOVA"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]

for file in files:
    with open(file, "r") as f:
        print(file)
        df = pd.read_csv(f, delim_whitespace=True, engine='python')
        for workload in workloads:
            s = df[(df['workloads'] == workload)]
            s = s.sum(axis=1).values[0]
            gc = df[(df['workloads'] == workload)]['GC(ns)'].values[0]
            jc = df[(df['workloads'] == workload)]['JC(ns)'].values[0]
        
            print(gc/s)
            
for file in files:
    with open(file, "r") as f:
        print(file)
        df = pd.read_csv(f, delim_whitespace=True, engine='python')
        for workload in workloads:
            s = df[(df['workloads'] == workload)]
            s = s.sum(axis=1).values[0]
            gc = df[(df['workloads'] == workload)]['GC(ns)'].values[0]
            jc = df[(df['workloads'] == workload)]['JC(ns)'].values[0]
            
            print(jc/s)
# Out:
# ./performance-comparison-table-NOVA
# 0.37966368069495704
# 0.3515585842795654
# 0.01050808914507862
# 0.06578154465715007
# 0.03441292622070513
# 0.03009075179186438
# ./performance-comparison-table-NOVA
# 0.09340691273178603
# 0.08693168832007585
# 0.12091377175132445
# 0.2353601325831926
# 0.019075381642644475
# 0.13292187581780052

# %% [markdown]
# # PMFS Overheads

# %%
import pandas as pd
import numpy as np

ops = [
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47087 * 60, 264382 * 60, 502315 * 60, 263680 * 60], # NOVA
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 31838 * 60, 107583 * 60, 171224 * 60, 113574 * 60], # SplitFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47205 * 60, 268363 * 60, 558425 * 60, 183316 * 60], # PMFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 79240 * 60, 437532 * 60, 580830 * 60, 344069 * 60], # KILLER
]
# "./performance-comparison-table-NOVA", 
files = ["./performance-comparison-table-PMFS"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]

for file in files:
    with open(file, "r") as f:
        print(file)
        df = pd.read_csv(f, delim_whitespace=True, engine='python')
        for workload in workloads:
            s = df[(df['workloads'] == workload)]
            s = s.sum(axis=1).values[0]
            jm = df[(df['workloads'] == workload)]['JM(ns)'].values[0]
            jc = df[(df['workloads'] == workload)]['JC(ns)'].values[0]
        
            print((jm+jc)/s)
# Out:
# ./performance-comparison-table-PMFS
# 0.4919447774596057
# 0.45854045312684905
# 0.37607978681580456
# 0.26891143788841676
# 0.0673214206606898
# 0.11338097794944309

# %% [markdown]
# # SplitFS Overheads

# %%
import pandas as pd
import numpy as np

ops = [
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47087 * 60, 264382 * 60, 502315 * 60, 263680 * 60], # NOVA
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 31838 * 60, 107583 * 60, 171224 * 60, 113574 * 60], # SplitFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47205 * 60, 268363 * 60, 558425 * 60, 183316 * 60], # PMFS
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 79240 * 60, 437532 * 60, 580830 * 60, 344069 * 60], # KILLER
]
# "./performance-comparison-table-NOVA", 
files = ["./performance-comparison-table-SplitFS"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]

for file in files:
    with open(file, "r") as f:
        print(file)
        df = pd.read_csv(f, delim_whitespace=True, engine='python')
        for workload in workloads:
            s = df[(df['workloads'] == workload)]
            s = s.sum(axis=1).values[0]
            jmc = df[(df['workloads'] == workload)]['JM|JC(ns)'].values[0]
        
            print((jmc)/s)
# Out:
# ./performance-comparison-table-SplitFS
# 0.05492868498155478
# 3.6374149154090064e-07
# 0.058973797418878336
# 0.06268778911020048
# 0.0013015511290460431
# 0.03996077362846036

# %% [markdown]
# # Calculation of Metadata Amplification

# %%
import pandas as pd
import numpy as np

files = ["./performance-comparison-table-NOVA", "./performance-comparison-table-PMFS"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]

real_meta_IOs_NOVA = []
real_meta_IOs_PMFS = []
software_meta_IO_percentages_NOVA = []
software_meta_IO_percentages_PMFS = []
meta_times_NOVA = []
meta_times_PMFS = []
meta_time_percentages_NOVA = []
meta_time_percentages_PMFS = []
WAs_NOVA = []
WAs_PMFS = []
RAs_NOVA = []
RAs_PMFS = []
IOAs_NOVA = []
IOAs_PMFS = []

for fid, file in enumerate(files):
    with open(file, "r") as f:
        df = pd.read_csv(f, delim_whitespace=True, engine='python')
    
    breakdown_times = df.columns[14:]
    breakdown_times = breakdown_times.insert(0, "data_read_time(ns)")
    breakdown_times = breakdown_times.insert(1, "data_write_time(ns)")
    
    print("=====================================")
    print(file)
    for workload_idx, workload in enumerate(workloads):
        total_time = 0
        meta_time = 0
        data_time = 0
        print(breakdown_times)
        for idx, breakdown_time in enumerate(breakdown_times):
            total_time += df[(df['workloads'] == workload)][breakdown_time].iloc[0]
            if idx == 0 or idx == 1:
                data_time += df[(df['workloads'] == workload)][breakdown_time].iloc[0]
            else:
                meta_time += df[(df['workloads'] == workload)][breakdown_time].iloc[0]
        # data_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["data_time(ns)"].iloc[0]
        # meta_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["meta_time(ns)"].iloc[0]
        # total_time = data_time + meta_time

        print("Total IO time of", workload, ": ", total_time / 1000000000)
        print("Meta IO time of", workload, ": ", meta_time / 1000000000)
        print("Data IO time of", workload, ": ", data_time / 1000000000)
        print("Meta IO time percentage of", workload, ": ", meta_time * 100 / total_time, "%")
        print("Data IO time percentage of", workload, ": ", data_time * 100 / total_time, "%")

        for breakdown_time in breakdown_times:
            print(breakdown_time + ": " + str(df[(df['workloads'] == workload)][breakdown_time].iloc[0] / 1000000000) + "s")
            print(breakdown_time + ": " + str(df[(df['workloads'] == workload)][breakdown_time].iloc[0] * 100 / total_time) + "%")

        data_write = df[(df['workloads'] == workload)]["data_write(bytes)"].iloc[0]
        data_read = df[(df['workloads'] == workload)]["data_read(bytes)"].iloc[0]
        media_write = df[(df['workloads'] == workload)]["media_write(byte)"].iloc[0]
        media_read = df[(df['workloads'] == workload)]["media_read(byte)"].iloc[0]
        meta_write = df[(df['workloads'] == workload)]["meta_write(bytes)"].iloc[0]
        meta_read = df[(df['workloads'] == workload)]["meta_read(bytes)"].iloc[0]

        software_meta_IO = meta_write + meta_read
        real_meta_IO = 0 if media_write + media_read - media_write - data_write - data_read < 0 else media_write + media_read - media_write - data_write - data_read 
        software_total_IO = software_meta_IO + data_write + data_read

        if fid == 0:
            real_meta_IOs_NOVA.append(real_meta_IO)
        else:
            real_meta_IOs_PMFS.append(real_meta_IO)

        print("workload: ", workload)
        print("software_meta_IO: ", software_meta_IO / 1024 / 1024 / 1024)
        print("real_meta_IO: ", real_meta_IO / 1024 / 1024 / 1024)
        print("software_meta_IO percentage: ", software_meta_IO * 100 / software_total_IO, "%")
        print("write amplification: ", media_write / (meta_write + data_write))
        print("read amplification: ", media_read / (meta_read + data_read))
        print("IO amplification: ", (media_write + media_read) / (meta_write + data_write + meta_read + data_read))

        software_meta_IO_percentages_NOVA.append(software_meta_IO * 100 / software_total_IO) if fid == 0 else software_meta_IO_percentages_PMFS.append(software_meta_IO * 100 / software_total_IO)
        meta_times_NOVA.append(meta_time / 1000000000) if fid == 0 else meta_times_PMFS.append(meta_time / 1000000000)
        meta_time_percentages_NOVA.append(meta_time * 100 / total_time) if fid == 0 else meta_time_percentages_PMFS.append(meta_time * 100 / total_time)
        WAs_NOVA.append(media_write / (meta_write + data_write)) if fid == 0 else WAs_PMFS.append(media_write / (meta_write + data_write))
        RAs_NOVA.append((media_read - media_write) / (meta_read + data_read)) if fid == 0 else RAs_PMFS.append((media_read - media_write) / (meta_read + data_read))
        IOAs_NOVA.append((media_write + media_read - media_write) / (meta_write + data_write + meta_read + data_read)) if fid == 0 else IOAs_PMFS.append((media_write + media_read - media_write) / (meta_write + data_write + meta_read + data_read))


    # for workload_idx, workload in enumerate(workloads):

def format_nice(array):
    return [round(x, 2) for x in array]

print("software_meta_IO_percentages_NOVA: ", format_nice(software_meta_IO_percentages_NOVA))
print("meta_time_percentages_NOVA: ", format_nice(meta_time_percentages_NOVA))
print("software_meta_IO_percentages_PMFS: ", format_nice(software_meta_IO_percentages_PMFS))
print("meta_time_percentages_PMFS: ", format_nice(meta_time_percentages_PMFS))
# print("meta_times_NOVA: ", meta_times_NOVA)
# print("meta_times_PMFS: ", meta_times_PMFS)
# Out:
# =====================================
# ./performance-comparison-table-NOVA
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_entry_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)',
#        'update_page_tail_time(ns)'],
#       dtype='object')
# Total IO time of write :  42.375228559
# Meta IO time of write :  31.990792054
# Data IO time of write :  10.384436505
# Meta IO time percentage of write :  75.49408732854027 %
# Data IO time percentage of write :  24.505912671459722 %
# data_read_time(ns): 0.0s
# data_read_time(ns): 0.0%
# data_write_time(ns): 10.384436505s
# data_write_time(ns): 24.505912671459722%
# update_entry_time(ns): 11.944316366s
# update_entry_time(ns): 28.187025231898527%
# update_inode_time(ns): 3.958139137s
# update_inode_time(ns): 9.340690945156773%
# journal_time(ns): 1.306e-06s
# journal_time(ns): 3.081989276309451e-06%
# update_page_tail_time(ns): 16.088335245s
# update_page_tail_time(ns): 37.9663680694957%
# workload:  write
# software_meta_IO:  4.1812749253585935
# real_meta_IO:  11.62866735458374
# software_meta_IO percentage:  11.55646099808395 %
# write amplification:  0.9952224151221222
# read amplification:  15.927921721209275
# IO amplification:  2.1257138825928314
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_entry_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)',
#        'update_page_tail_time(ns)'],
#       dtype='object')
# Total IO time of randwrite :  45.599658762
# Meta IO time of randwrite :  31.427762226
# Data IO time of randwrite :  14.171896536
# Meta IO time percentage of randwrite :  68.92104695351361 %
# Data IO time percentage of randwrite :  31.078953046486397 %
# data_read_time(ns): 0.0s
# data_read_time(ns): 0.0%
# data_write_time(ns): 14.171896536s
# data_write_time(ns): 31.078953046486397%
# update_entry_time(ns): 11.4327537s
# update_entry_time(ns): 25.072015910626433%
# update_inode_time(ns): 3.964055183s
# update_inode_time(ns): 8.693168524987744%
# journal_time(ns): 1.865e-06s
# journal_time(ns): 4.089942886928308e-06%
# update_page_tail_time(ns): 16.030951478s
# update_page_tail_time(ns): 35.15585842795654%
# workload:  randwrite
# software_meta_IO:  4.1812749253585935
# real_meta_IO:  13.057440996170044
# software_meta_IO percentage:  11.55646099808395 %
# write amplification:  1.0123551211172435
# read amplification:  16.44953734919895
# IO amplification:  2.1810388555792963
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_entry_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)',
#        'update_page_tail_time(ns)'],
#       dtype='object')
# Total IO time of fileserver.f :  36.392994456
# Meta IO time of fileserver.f :  13.966131472
# Data IO time of fileserver.f :  22.426862984
# Meta IO time percentage of fileserver.f :  38.375878876593646 %
# Data IO time percentage of fileserver.f :  61.624121123406354 %
# data_read_time(ns): 14.137346548s
# data_read_time(ns): 38.84634050955161%
# data_write_time(ns): 8.289516436s
# data_write_time(ns): 22.777780613854745%
# update_entry_time(ns): 8.767076221s
# update_entry_time(ns): 24.090010596955974%
# update_inode_time(ns): 4.285774497s
# update_inode_time(ns): 11.776372241590627%
# journal_time(ns): 0.530859924s
# journal_time(ns): 1.458687123539181%
# update_page_tail_time(ns): 0.38242083s
# update_page_tail_time(ns): 1.050808914507862%
# workload:  fileserver.f
# software_meta_IO:  3.140807938762009
# real_meta_IO:  7.159661753103137
# software_meta_IO percentage:  5.365310792548727 %
# write amplification:  1.0327253418036821
# read amplification:  2.1845427684516068
# IO amplification:  1.5961807582455922
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_entry_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)',
#        'update_page_tail_time(ns)'],
#       dtype='object')
# Total IO time of varmail.f :  27.011784601
# Meta IO time of varmail.f :  15.200243042
# Data IO time of varmail.f :  11.811541559
# Meta IO time percentage of varmail.f :  56.27263532020492 %
# Data IO time percentage of varmail.f :  43.72736467979508 %
# data_read_time(ns): 4.037550969s
# data_read_time(ns): 14.947368449141736%
# data_write_time(ns): 7.77399059s
# data_write_time(ns): 28.779996230653342%
# update_entry_time(ns): 5.082665916s
# update_entry_time(ns): 18.81647581260453%
# update_inode_time(ns): 5.748331339s
# update_inode_time(ns): 21.280827697653088%
# journal_time(ns): 2.592368872s
# journal_time(ns): 9.597177344232296%
# update_page_tail_time(ns): 1.776876915s
# update_page_tail_time(ns): 6.578154465715007%
# workload:  varmail.f
# software_meta_IO:  3.819047295488417
# real_meta_IO:  21.248093018308282
# software_meta_IO percentage:  26.041233278665896 %
# write amplification:  2.477458328929281
# read amplification:  3.775380062261496
# IO amplification:  3.229815429013997
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_entry_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)',
#        'update_page_tail_time(ns)'],
#       dtype='object')
# Total IO time of webserver.f :  23.940865119
# Meta IO time of webserver.f :  2.716036232
# Data IO time of webserver.f :  21.224828887
# Meta IO time percentage of webserver.f :  11.344770619189084 %
# Data IO time percentage of webserver.f :  88.65522938081091 %
# data_read_time(ns): 14.061560048s
# data_read_time(ns): 58.73455273276835%
# data_write_time(ns): 7.163268839s
# data_write_time(ns): 29.920676648042562%
# update_entry_time(ns): 1.434533633s
# update_entry_time(ns): 5.991987448530097%
# update_inode_time(ns): 0.456531926s
# update_inode_time(ns): 1.906914907756137%
# journal_time(ns): 0.001095448s
# journal_time(ns): 0.004575640832338294%
# update_page_tail_time(ns): 0.823875225s
# update_page_tail_time(ns): 3.441292622070513%
# workload:  webserver.f
# software_meta_IO:  0.5084441099315882
# real_meta_IO:  0.0
# software_meta_IO percentage:  0.3533676126934051 %
# write amplification:  1.572200707287969
# read amplification:  0.20762579687566857
# IO amplification:  0.2749797857906542
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_entry_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)',
#        'update_page_tail_time(ns)'],
#       dtype='object')
# Total IO time of webproxy.f :  31.624613256
# Meta IO time of webproxy.f :  9.894031731
# Data IO time of webproxy.f :  21.730581525
# Meta IO time percentage of webproxy.f :  31.285858425866593 %
# Data IO time percentage of webproxy.f :  68.71414157413341 %
# data_read_time(ns): 16.104976297s
# data_read_time(ns): 50.92544900590831%
# data_write_time(ns): 5.625605228s
# data_write_time(ns): 17.788692568225095%
# update_entry_time(ns): 3.296293072s
# update_entry_time(ns): 10.423188563024114%
# update_inode_time(ns): 3.818975048s
# update_inode_time(ns): 12.075958106066143%
# journal_time(ns): 1.827155223s
# journal_time(ns): 5.7776365775899%
# update_page_tail_time(ns): 0.951608388s
# update_page_tail_time(ns): 3.009075179186438%
# workload:  webproxy.f
# software_meta_IO:  2.3990774201229215
# real_meta_IO:  11.14461886882782
# software_meta_IO percentage:  6.456576905199573 %
# write amplification:  1.4473234461506306
# read amplification:  1.5177045755537166
# IO amplification:  1.5046116005183894
# =====================================
# ./performance-comparison-table-PMFS
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_index_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)', 'update_dentry_time(ns)'],
#       dtype='object')
# Total IO time of write :  32.753580854
# Meta IO time of write :  22.726393049
# Data IO time of write :  10.027187805
# Meta IO time percentage of write :  69.38597996446109 %
# Data IO time percentage of write :  30.61402003553892 %
# data_read_time(ns): 0.0s
# data_read_time(ns): 0.0%
# data_write_time(ns): 10.027187805s
# data_write_time(ns): 30.61402003553892%
# update_index_time(ns): 4.106834985s
# update_index_time(ns): 12.538583195853704%
# update_inode_time(ns): 5.883068923s
# update_inode_time(ns): 17.961605325609874%
# journal_time(ns): 12.736487526s
# journal_time(ns): 38.885786512238916%
# update_dentry_time(ns): 1.615e-06s
# update_dentry_time(ns): 4.930758585447214e-06%
# workload:  write
# software_meta_IO:  2.8710703626275063
# real_meta_IO:  8.037137985229492
# software_meta_IO percentage:  8.233387540935734 %
# write amplification:  1.06375461640291
# read amplification:  26.80138725433938
# IO amplification:  2.166331976112748
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_index_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)', 'update_dentry_time(ns)'],
#       dtype='object')
# Total IO time of randwrite :  37.1555297
# Meta IO time of randwrite :  25.008769617
# Data IO time of randwrite :  12.146760083
# Meta IO time percentage of randwrite :  67.30833827138252 %
# Data IO time percentage of randwrite :  32.691661728617476 %
# data_read_time(ns): 0.0s
# data_read_time(ns): 0.0%
# data_write_time(ns): 12.146760083s
# data_write_time(ns): 32.691661728617476%
# update_index_time(ns): 5.848615233s
# update_index_time(ns): 15.740901233874752%
# update_inode_time(ns): 5.92956181s
# update_inode_time(ns): 15.958759995823717%
# journal_time(ns): 13.230591268s
# journal_time(ns): 35.608673526729454%
# update_dentry_time(ns): 1.306e-06s
# update_dentry_time(ns): 3.514954599072773e-06%
# workload:  randwrite
# software_meta_IO:  2.814686007797718
# real_meta_IO:  13.397818565368652
# software_meta_IO percentage:  8.084766317200996 %
# write amplification:  1.1345358507796413
# read amplification:  30.265994163947305
# IO amplification:  2.3896400541588196
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_index_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)', 'update_dentry_time(ns)'],
#       dtype='object')
# Total IO time of fileserver.f :  31.246544369
# Meta IO time of fileserver.f :  15.156740364
# Data IO time of fileserver.f :  16.089804005
# Meta IO time percentage of fileserver.f :  48.5069330707723 %
# Data IO time percentage of fileserver.f :  51.4930669292277 %
# data_read_time(ns): 9.409613237s
# data_read_time(ns): 30.114092380517345%
# data_write_time(ns): 6.680190768s
# data_write_time(ns): 21.37897454871036%
# update_index_time(ns): 2.294039637s
# update_index_time(ns): 7.341738689273874%
# update_inode_time(ns): 3.579161207s
# update_inode_time(ns): 11.454582512333493%
# journal_time(ns): 9.051357045s
# journal_time(ns): 28.967545780774206%
# update_dentry_time(ns): 0.232182475s
# update_dentry_time(ns): 0.743066088390723%
# workload:  fileserver.f
# software_meta_IO:  3.9477668292820454
# real_meta_IO:  9.431772249750793
# software_meta_IO percentage:  9.153658221914345 %
# write amplification:  1.096402596411104
# read amplification:  2.269704619846796
# IO amplification:  1.6790757128081675
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_index_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)', 'update_dentry_time(ns)'],
#       dtype='object')
# Total IO time of varmail.f :  31.032438666
# Meta IO time of varmail.f :  23.133052449
# Data IO time of varmail.f :  7.899386217
# Meta IO time percentage of varmail.f :  74.54474557407315 %
# Data IO time percentage of varmail.f :  25.45525442592685 %
# data_read_time(ns): 3.11916794s
# data_read_time(ns): 10.051314283003633%
# data_write_time(ns): 4.780218277s
# data_write_time(ns): 15.403940142923217%
# update_index_time(ns): 1.356219798s
# update_index_time(ns): 4.370329423984045%
# update_inode_time(ns): 2.260165762s
# update_inode_time(ns): 7.283236056070257%
# journal_time(ns): 6.406210826s
# journal_time(ns): 20.64359457840103%
# update_dentry_time(ns): 13.110456063s
# update_dentry_time(ns): 42.24758551561782%
# workload:  varmail.f
# software_meta_IO:  24.46027087699622
# real_meta_IO:  13.682255900464952
# software_meta_IO percentage:  76.4196020607073 %
# write amplification:  1.9486254730706782
# read amplification:  0.7886039248692058
# IO amplification:  0.9729683219687435
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_index_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)', 'update_dentry_time(ns)'],
#       dtype='object')
# Total IO time of webserver.f :  24.005036673
# Meta IO time of webserver.f :  5.178647303
# Data IO time of webserver.f :  18.82638937
# Meta IO time percentage of webserver.f :  21.573169720772622 %
# Data IO time percentage of webserver.f :  78.42683027922737 %
# data_read_time(ns): 13.245268159s
# data_read_time(ns): 55.1770378001455%
# data_write_time(ns): 5.581121211s
# data_write_time(ns): 23.249792479081876%
# update_index_time(ns): 1.612952628s
# update_index_time(ns): 6.719225844025437%
# update_inode_time(ns): 2.332780374s
# update_inode_time(ns): 9.717878817589257%
# journal_time(ns): 1.232001678s
# journal_time(ns): 5.132263261175148%
# update_dentry_time(ns): 0.000912623s
# update_dentry_time(ns): 0.0038017979827811945%
# workload:  webserver.f
# software_meta_IO:  1.0142115652561188
# real_meta_IO:  0.0
# software_meta_IO percentage:  0.9209895119255959 %
# write amplification:  1.3777616703335638
# read amplification:  0.17181374741965438
# IO amplification:  0.23013876299233413
# Index(['data_read_time(ns)', 'data_write_time(ns)', 'update_index_time(ns)',
#        'update_inode_time(ns)', 'journal_time(ns)', 'update_dentry_time(ns)'],
#       dtype='object')
# Total IO time of webproxy.f :  39.705072678
# Meta IO time of webproxy.f :  27.297150857
# Data IO time of webproxy.f :  12.407921821
# Meta IO time percentage of webproxy.f :  68.74978186886672 %
# Data IO time percentage of webproxy.f :  31.250218131133273 %
# data_read_time(ns): 9.263755745s
# data_read_time(ns): 23.331416164698048%
# data_write_time(ns): 3.144166076s
# data_write_time(ns): 7.918801966435227%
# update_index_time(ns): 1.917442007s
# update_index_time(ns): 4.8292116791979245%
# update_inode_time(ns): 1.863601928s
# update_inode_time(ns): 4.693611678068013%
# journal_time(ns): 3.340947598s
# journal_time(ns): 8.414409980040586%
# update_dentry_time(ns): 20.175159324s
# update_dentry_time(ns): 50.8125485315602%
# workload:  webproxy.f
# software_meta_IO:  25.960262808017433
# real_meta_IO:  9.12499481253326
# software_meta_IO percentage:  58.0731640280645 %
# write amplification:  1.4179808234225062
# read amplification:  0.6961085952237405
# IO amplification:  0.7715137093859498
# software_meta_IO_percentages_NOVA:  [11.56, 11.56, 5.37, 26.04, 0.35, 6.46]
# meta_time_percentages_NOVA:  [75.49, 68.92, 38.38, 56.27, 11.34, 31.29]
# software_meta_IO_percentages_PMFS:  [8.23, 8.08, 9.15, 76.42, 0.92, 58.07]
# meta_time_percentages_PMFS:  [69.39, 67.31, 48.51, 74.54, 21.57, 68.75]

# %% [markdown]
# # KILLER

# %%
import pandas as pd
import numpy as np

files = ["./performance-comparison-table-KILLER"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]
real_meta_IOs_of_KILLER = []
package_persist_time_percentages = []
WAs_KILLER = []
RAs_KILLER = []
IOAs_KILLER = []
meta_times_KILLER = []

for fid, file in enumerate(files):
    with open(file, "r") as f:
        df = pd.read_csv(f, delim_whitespace=True, engine='python')

    for workload_idx, workload in enumerate(workloads):
        data_write = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["data_write(bytes)"].iloc[0]
        data_read = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["data_read(bytes)"].iloc[0]
        media_write = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["media_write(byte)"].iloc[0]
        media_read = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["media_read(byte)"].iloc[0]
        meta_write = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["meta_write(bytes)"].iloc[0]
        meta_read = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["meta_read(bytes)"].iloc[0]

        data_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["data_time(ns)"].iloc[0]
        meta_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["meta_time(ns)"].iloc[0]
        total_time = data_time + meta_time

        meta_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["meta_time(ns)"].iloc[0]
        update_bm_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["update_bm_time(ns)"].iloc[0]
        update_package_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER")]["update_package_time(ns)"].iloc[0]

        software_meta_IO = meta_write + meta_read
        real_meta_IO = 0 if media_write + media_read - media_write - data_write - data_read < 0 else media_write + media_read - media_write - data_write - data_read 
        software_total_IO = software_meta_IO + data_write + data_read
        
        real_meta_IOs_of_KILLER.append(real_meta_IO)
        meta_times_KILLER.append(meta_time / 1000000000)
        
        print("workload: ", workload)
        print("software_meta_IO: ", software_meta_IO / 1024 / 1024 / 1024)
        print("real_meta_IO: ", real_meta_IO / 1024 / 1024 / 1024)
        print("software_meta_IO percentage: ", software_meta_IO * 100 / software_total_IO, "%")
        print("Total IO time (seconds) of", workload, ": ", total_time / 1000000000)
        print("meta percentage: ", meta_time * 100 / total_time, "%")
        print("meta time: ", meta_time / 1000000000, "s")
        print("bm percentage: ", update_bm_time * 100 / total_time, "%")
        print("bm time: ", update_bm_time / 1000000000, "s")
        print("package percentage: ", update_package_time * 100 / total_time, "%")
        print("package time: ", update_package_time / 1000000000, "s")
        print("write amplification: ", media_write / (meta_write + data_write))
        print("read amplification: ", media_read / (meta_read + data_read))
        print("IO amplification: ", (media_write + media_read) / (meta_write + data_write + meta_read + data_read))
        print("")
        package_persist_time_percentages.append(update_package_time * 100 / total_time)
        WAs_KILLER.append(media_write / (meta_write + data_write))
        RAs_KILLER.append((media_read - media_write) / (meta_read + data_read))
        IOAs_KILLER.append((media_write + media_read - media_write) / (meta_write + data_write + meta_read + data_read))
        # software_meta_IO = meta_write + meta_read
        # real_meta_IO = 0 if media_write + media_read - media_write - data_write - data_read < 0 else media_write + media_read - media_write - data_write - data_read 
        
        # print("workload: ", workload)
        # print("software_meta_IO: ", software_meta_IO / 1024 / 1024 / 1024)
        # print("real_meta_IO: ", real_meta_IO / 1024 / 1024 / 1024)
print("real_meta_IOs_of_KILLER: ", format_nice(real_meta_IOs_of_KILLER))
print("package_persist_time_percentages: ", format_nice(package_persist_time_percentages))

print("WAs_NOVA: ", format_nice(WAs_NOVA))
print("RAs_NOVA: ", format_nice(RAs_NOVA))
print("IOAs_NOVA: ", format_nice(IOAs_NOVA))
print("WAs_PMFS: ", format_nice(WAs_PMFS))
print("RAs_PMFS: ", format_nice(RAs_PMFS))
print("IOAs_PMFS: ", format_nice(IOAs_PMFS))
print("WAs_KILLER: ", format_nice(WAs_KILLER))
print("RAs_KILLER: ", format_nice(RAs_KILLER))
print("IOAs_KILLER: ", format_nice(IOAs_KILLER))
# Out:
# workload:  write
# software_meta_IO:  0.06335536669939756
# real_meta_IO:  0.634427547454834
# software_meta_IO percentage:  0.19759431280606915 %
# Total IO time (seconds) of write :  9.916641786
# meta percentage:  33.69344658306689 %
# meta time:  3.341258403 s
# bm percentage:  0.0023833169040517765 %
# bm time:  0.000236345 s
# package percentage:  33.691063266162836 %
# package time:  3.341022058 s
# write amplification:  1.0049284226749344
# read amplification:  inf
# IO amplification:  2.022739165631317
#
# workload:  randwrite
# software_meta_IO:  0.5001223925501108
# real_meta_IO:  2.960953712463379
# software_meta_IO percentage:  1.5388323357968403 %
# Total IO time (seconds) of randwrite :  21.448647251
# meta percentage:  46.913967632764624 %
# meta time:  10.062411429 s
# bm percentage:  0.25836513767746516 %
# bm time:  0.055415827 s
# package percentage:  46.65560249508716 %
# package time:  10.006995602 s
# write amplification:  1.02104277864672
# read amplification:  inf
# IO amplification:  2.096760380266502
#
# workload:  fileserver.f
# software_meta_IO:  0.38695345167070627
# real_meta_IO:  4.167887169867754
# software_meta_IO percentage:  0.44875290714858357 %
# Total IO time (seconds) of fileserver.f :  40.665266915
# meta percentage:  26.624391030386526 %
# meta time:  10.826879677 s
# bm percentage:  0.19056131160279144 %
# bm time:  0.077492266 s
# package percentage:  26.433829718783734 %
# package time:  10.749387411 s
# write amplification:  1.0245491169741188
# read amplification:  2.1345151266088167
# IO amplification:  1.5673588356986485
#
# workload:  varmail.f
# software_meta_IO:  0.6271651387214661
# real_meta_IO:  12.165626836009324
# software_meta_IO percentage:  3.8164367677147384 %
# Total IO time (seconds) of varmail.f :  25.491503741
# meta percentage:  52.22047488547961 %
# meta time:  13.311784309 s
# bm percentage:  0.5831396394278332 %
# bm time:  0.148651063 s
# package percentage:  51.63733524605178 %
# package time:  13.163133246 s
# write amplification:  1.8993013945758166
# read amplification:  2.9579846078283842
# IO amplification:  2.508509317607254
#
# workload:  webserver.f
# software_meta_IO:  0.008406104519963264
# real_meta_IO:  0.0
# software_meta_IO percentage:  0.00496160807299459 %
# Total IO time (seconds) of webserver.f :  23.945083935
# meta percentage:  2.3902350125547804 %
# meta time:  0.57234378 s
# bm percentage:  0.0003747157464286416 %
# bm time:  8.9726e-05 s
# package percentage:  2.3898602968083518 %
# package time:  0.572254054 s
# write amplification:  1.0909377484719305
# read amplification:  0.1720054777483482
# IO amplification:  0.21584145466988094
#
# workload:  webproxy.f
# software_meta_IO:  0.41971178259700537
# real_meta_IO:  8.534388720989227
# software_meta_IO percentage:  0.9553675561451611 %
# Total IO time (seconds) of webproxy.f :  30.719361213
# meta percentage:  25.782197224362577 %
# meta time:  7.920126294 s
# bm percentage:  0.33629320051187095 %
# bm time:  0.103307123 s
# package percentage:  25.445904023850705 %
# package time:  7.816819171 s
# write amplification:  1.3230224181803694
# read amplification:  1.437460512998611
# IO amplification:  1.4173387222143095
#
# real_meta_IOs_of_KILLER:  [681211392, 3179299840, 4475234772, 13062742349, 0, 9163730112]
# package_persist_time_percentages:  [33.69, 46.66, 26.43, 51.64, 2.39, 25.45]
# WAs_NOVA:  [1.0, 1.01, 1.03, 2.48, 1.57, 1.45]
# RAs_NOVA:  [3.78, 4.09, 1.11, 1.98, 0.13, 1.19]
# IOAs_NOVA:  [1.21, 1.25, 1.07, 2.19, 0.2, 1.24]
# WAs_PMFS:  [1.06, 1.13, 1.1, 1.95, 1.38, 1.42]
# RAs_PMFS:  [3.03, 5.07, 1.16, 0.42, 0.1, 0.53]
# IOAs_PMFS:  [1.15, 1.3, 1.13, 0.66, 0.16, 0.62]
# WAs_KILLER:  [1.0, 1.02, 1.02, 1.9, 1.09, 1.32]
# RAs_KILLER:  [inf, inf, 1.06, 1.56, 0.12, 1.16]
# IOAs_KILLER:  [1.02, 1.08, 1.04, 1.7, 0.16, 1.18]
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:52: RuntimeWarning: divide by zero encountered in long_scalars
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: RuntimeWarning: divide by zero encountered in long_scalars

# %% [markdown]
# # Reduced Metadata I/Os per Operations

# %%
min_amps = []
max_amps = []

min_times = []
max_times = []

ops = [
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47087 * 60, 264382 * 60, 502315 * 60, 263680 * 60],
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 47205 * 60, 268363 * 60, 558425 * 60, 183316 * 60],
    [32 * 1024 * 1024 / 4, 32 * 1024 * 1024 / 4, 79240 * 60, 437532 * 60, 580830 * 60, 344069 * 60]
]

for idx, meta_IO in enumerate(real_meta_IOs_of_KILLER):
    if meta_IO == 0:
        continue
    meta_IO_KILLER_per_op = meta_IO / ops[2][idx]
    amp_NOVA = real_meta_IOs_NOVA[idx] / meta_IO_KILLER_per_op / ops[0][idx] 
    amp_PMFS = real_meta_IOs_PMFS[idx] / meta_IO_KILLER_per_op / ops[1][idx]
    min_amp = min(amp_NOVA, amp_PMFS)
    min_amps.append(min_amp)
    max_amp = max(amp_NOVA, amp_PMFS)
    max_amps.append(max_amp)

for idx, meta_time in enumerate(meta_times_KILLER):
    if meta_time == 0:
        continue
    meta_time_KILLER_per_op = meta_time / ops[2][idx]
    time_NOVA = meta_times_NOVA[idx] / meta_time_KILLER_per_op / ops[0][idx] 
    time_PMFS = meta_times_PMFS[idx] / meta_time_KILLER_per_op / ops[1][idx]
    min_time = min(time_NOVA, time_PMFS)
    min_times.append(min_time)
    max_time = max(time_NOVA, time_PMFS)
    max_times.append(max_time)
    print(time_NOVA, time_PMFS)
    
print("min_amps: ", min_amps)
print("max_amps: ", max_amps)
print("min-max: ", min(min_amps), max(max_amps))

print("min_times: ", min_times)
print("max_times: ", max_times)
print("min-max: ", min(min_times), max(max_times))
# Out:
# 9.574474103911442 6.801746619954553
# 3.1232833648030707 2.4853654408250887
# 2.1707822456589856 2.349951860710183
# 1.8896971065053512 2.833243192564914
# 5.487208773440336 9.411168589012506
# 1.6300823579927044 6.468899230453607
# min_amps:  [12.668330713999568, 4.409876770855309, 2.8908129858660234, 1.8336244927792262, 1.7039669067088856]
# max_amps:  [18.329385918431615, 4.524832154239343, 3.7986896773779764, 2.890436322241741, 2.0068059460788397]
# min-max:  1.7039669067088856 18.329385918431615
# min_times:  [6.801746619954553, 2.4853654408250887, 2.1707822456589856, 1.8896971065053512, 5.487208773440336, 1.6300823579927044]
# max_times:  [9.574474103911442, 3.1232833648030707, 2.349951860710183, 2.833243192564914, 9.411168589012506, 6.468899230453607]
# min-max:  1.6300823579927044 9.574474103911442

# %% [markdown]
# # KILLER-NAIVE

# %%
import pandas as pd
import numpy as np

files = ["./performance-comparison-table-KILLER"] 
workloads = ["write", "randwrite", "fileserver.f", "varmail.f", "webserver.f", "webproxy.f"]
real_meta_IOs_of_KILLER = []
package_persist_time_percentages = []
WAs_KILLER = []
RAs_KILLER = []
IOAs_KILLER = []
meta_times_KILLER = []

for fid, file in enumerate(files):
    with open(file, "r") as f:
        df = pd.read_csv(f, delim_whitespace=True, engine='python')

    for workload_idx, workload in enumerate(workloads):
        data_write = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["data_write(bytes)"].iloc[0]
        data_read = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["data_read(bytes)"].iloc[0]
        media_write = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["media_write(byte)"].iloc[0]
        media_read = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["media_read(byte)"].iloc[0]
        meta_write = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["meta_write(bytes)"].iloc[0]
        meta_read = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["meta_read(bytes)"].iloc[0]

        data_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["data_time(ns)"].iloc[0]
        meta_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["meta_time(ns)"].iloc[0]
        total_time = data_time + meta_time

        meta_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["meta_time(ns)"].iloc[0]
        update_bm_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["update_bm_time(ns)"].iloc[0]
        update_package_time = df[(df['workloads'] == workload) & (df['file_system']=="KILLER-NAIVE")]["update_package_time(ns)"].iloc[0]

        software_meta_IO = meta_write + meta_read
        real_meta_IO = 0 if media_write + media_read - media_write - data_write - data_read < 0 else media_write + media_read - media_write - data_write - data_read 
        software_total_IO = software_meta_IO + data_write + data_read
        
        real_meta_IOs_of_KILLER.append(real_meta_IO)
        meta_times_KILLER.append(meta_time / 1000000000)
        
        print("workload: ", workload)
        print("software_meta_IO: ", software_meta_IO / 1024 / 1024 / 1024)
        print("real_meta_IO: ", real_meta_IO / 1024 / 1024 / 1024)
        print("software_meta_IO percentage: ", software_meta_IO * 100 / software_total_IO, "%")
        print("Total IO time (seconds) of", workload, ": ", total_time / 1000000000)
        print("meta percentage: ", meta_time * 100 / total_time, "%")
        print("meta time: ", meta_time / 1000000000, "s")
        print("bm percentage: ", update_bm_time * 100 / total_time, "%")
        print("bm time: ", update_bm_time / 1000000000, "s")
        print("package percentage: ", update_package_time * 100 / total_time, "%")
        print("package time: ", update_package_time / 1000000000, "s")
        print("write amplification: ", media_write / (meta_write + data_write))
        print("read amplification: ", media_read / (meta_read + data_read))
        print("IO amplification: ", (media_write + media_read) / (meta_write + data_write + meta_read + data_read))
        print("")
        package_persist_time_percentages.append(update_package_time * 100 / total_time)
        WAs_KILLER.append(media_write / (meta_write + data_write))
        RAs_KILLER.append((media_read - media_write) / (meta_read + data_read))
        IOAs_KILLER.append((media_write + media_read - media_write) / (meta_write + data_write + meta_read + data_read))
        # software_meta_IO = meta_write + meta_read
        # real_meta_IO = 0 if media_write + media_read - media_write - data_write - data_read < 0 else media_write + media_read - media_write - data_write - data_read 
        
        # print("workload: ", workload)
        # print("software_meta_IO: ", software_meta_IO / 1024 / 1024 / 1024)
        # print("real_meta_IO: ", real_meta_IO / 1024 / 1024 / 1024)
print("real_meta_IOs_of_KILLER: ", format_nice(real_meta_IOs_of_KILLER))
print("package_persist_time_percentages: ", format_nice(package_persist_time_percentages))

print("WAs_NOVA: ", format_nice(WAs_NOVA))
print("RAs_NOVA: ", format_nice(RAs_NOVA))
print("IOAs_NOVA: ", format_nice(IOAs_NOVA))
print("WAs_PMFS: ", format_nice(WAs_PMFS))
print("RAs_PMFS: ", format_nice(RAs_PMFS))
print("IOAs_PMFS: ", format_nice(IOAs_PMFS))
print("WAs_KILLER: ", format_nice(WAs_KILLER))
print("RAs_KILLER: ", format_nice(RAs_KILLER))
print("IOAs_KILLER: ", format_nice(IOAs_KILLER))
# Out:
# workload:  write
# software_meta_IO:  0.5001225490123034
# real_meta_IO:  2.6450347900390625
# software_meta_IO percentage:  1.5388328098089044 %
# Total IO time (seconds) of write :  20.038333614
# meta percentage:  45.67877864157811 %
# meta time:  9.153266055 s
# bm percentage:  0.26156007784690033 %
# bm time:  0.052412281 s
# package percentage:  45.41721856373121 %
# package time:  9.100853774 s
# write amplification:  1.0174780699533537
# read amplification:  inf
# IO amplification:  2.0834751208196107
#
# workload:  randwrite
# software_meta_IO:  0.5001225490123034
# real_meta_IO:  2.9326424598693848
# software_meta_IO percentage:  1.5388328098089044 %
# Total IO time (seconds) of randwrite :  21.235862864
# meta percentage:  46.29368261586265 %
# meta time:  9.830862955 s
# bm percentage:  0.2566744113440419 %
# bm time:  0.054507026 s
# package percentage:  46.03700820451861 %
# package time:  9.776355929 s
# write amplification:  1.0205847550279368
# read amplification:  inf
# IO amplification:  2.0954312392893018
#
# workload:  fileserver.f
# software_meta_IO:  0.6798819284886122
# real_meta_IO:  5.05387881398201
# software_meta_IO percentage:  0.8925742892621034 %
# Total IO time (seconds) of fileserver.f :  41.416805621
# meta percentage:  23.68391415012069 %
# meta time:  9.809120687 s
# bm percentage:  0.29384999923386534 %
# bm time:  0.121703283 s
# package percentage:  23.390064150886825 %
# package time:  9.687417404 s
# write amplification:  1.0329885160562915
# read amplification:  2.1753879627412713
# IO amplification:  1.588291751358089
#
# workload:  varmail.f
# software_meta_IO:  0.6974155781790614
# real_meta_IO:  13.300197164528072
# software_meta_IO percentage:  3.838132995837277 %
# Total IO time (seconds) of varmail.f :  23.224245993
# meta percentage:  37.12809750464651 %
# meta time:  8.622720697 s
# bm percentage:  0.6213546611739078 %
# bm time:  0.144304935 s
# package percentage:  36.5067428434726 %
# package time:  8.478415762 s
# write amplification:  1.9047308696188763
# read amplification:  2.9429487999122226
# IO amplification:  2.5021935837106466
#
# workload:  webserver.f
# software_meta_IO:  0.05839345511049032
# real_meta_IO:  0.0
# software_meta_IO percentage:  0.03329322379964599 %
# Total IO time (seconds) of webserver.f :  22.57581361
# meta percentage:  4.7438751599437925 %
# meta time:  1.070968414 s
# bm percentage:  0.0352695727274832 %
# bm time:  0.007962393 s
# package percentage:  4.70860558721631 %
# package time:  1.063006021 s
# write amplification:  1.3264188254402995
# read amplification:  0.1039574244512028
# IO amplification:  0.16258865559343272
#
# workload:  webproxy.f
# software_meta_IO:  0.4069866817444563
# real_meta_IO:  8.148602481931448
# software_meta_IO percentage:  0.956546755761111 %
# Total IO time (seconds) of webproxy.f :  32.287754284
# meta percentage:  18.297656895040312 %
# meta time:  5.907902498 s
# bm percentage:  0.28258220809495305 %
# bm time:  0.091239449 s
# package percentage:  18.01507468694536 %
# package time:  5.816663049 s
# write amplification:  1.3221643602245068
# read amplification:  1.434199965103782
# IO amplification:  1.414495100278433
#
# real_meta_IOs_of_KILLER:  [2840084480, 3148900864, 5426561056, 14280977963, 0, 8749495292]
# package_persist_time_percentages:  [45.42, 46.04, 23.39, 36.51, 4.71, 18.02]
# WAs_NOVA:  [1.0, 1.01, 1.03, 2.48, 1.57, 1.45]
# RAs_NOVA:  [3.78, 4.09, 1.11, 1.98, 0.13, 1.19]
# IOAs_NOVA:  [1.21, 1.25, 1.07, 2.19, 0.2, 1.24]
# WAs_PMFS:  [1.06, 1.13, 1.1, 1.95, 1.38, 1.42]
# RAs_PMFS:  [3.03, 5.07, 1.16, 0.42, 0.1, 0.53]
# IOAs_PMFS:  [1.15, 1.3, 1.13, 0.66, 0.16, 0.62]
# WAs_KILLER:  [1.02, 1.02, 1.03, 1.9, 1.33, 1.32]
# RAs_KILLER:  [inf, inf, 1.08, 1.54, 0.04, 1.15]
# IOAs_KILLER:  [1.07, 1.07, 1.06, 1.69, 0.1, 1.18]
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:52: RuntimeWarning: divide by zero encountered in long_scalars
# /home/deadpool/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: RuntimeWarning: divide by zero encountered in long_scalars
